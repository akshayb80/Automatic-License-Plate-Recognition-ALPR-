# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.layers import Conv2D, Dropout, Flatten, Dense, Input, MaxPooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array, load_img
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import model_from_json, Sequential
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import glob
import numpy as np

# %%
dataset_paths = glob.glob("dataset_characters/**/*.jpg")

# %%
# Arange input data and corresponding labels
X=[]
labels=[]

for image_path in dataset_paths:
  label = image_path.split(os.path.sep)[-2]
  image=load_img(image_path,target_size=(80,80))
  image=img_to_array(image)

  X.append(image)
  labels.append(label)

X = np.array(X,dtype="float16")
labels = np.array(labels)

print("[INFO] Find {:d} images with {:d} classes".format(len(X),len(set(labels))))

# perform one-hot encoding on the labels
lb = LabelEncoder()
lb.fit(labels)
labels = lb.transform(labels)
y = to_categorical(labels)

# save label file so we can use in another script
np.save('license_character_classes.npy', lb.classes_)

# split 10% of data as validation set
(trainX, testX, trainY, testY) = train_test_split(X, y, test_size=0.10, stratify=y, random_state=42)


# generate data augumentation method
image_gen = ImageDataGenerator(rotation_range=10,
                              width_shift_range=0.1,
                              height_shift_range=0.1,
                              shear_range=0.1,
                              zoom_range=0.1,
                              fill_mode="nearest"
                              )
# Out:
# [INFO] Find 37623 images with 36 classes

# %%
model = Sequential()
model.add(Conv2D(32, (24,24), input_shape=(80, 80, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (20,20), input_shape=(80, 80, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (20,20), input_shape=(80, 80, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(36, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=0.00001), metrics=['accuracy'])

# %%
BATCH_SIZE = 64

my_checkpointer = [
                EarlyStopping(monitor='val_loss', patience=5, verbose=0),
                ModelCheckpoint(filepath="License_character_recognition.h5", verbose=1, save_weights_only=True)
                ]

result = model.fit(image_gen.flow(trainX, trainY, batch_size=BATCH_SIZE), 
                   steps_per_epoch=len(trainX) // BATCH_SIZE, 
                   validation_data=(testX, testY), 
                   validation_steps=len(testX) // BATCH_SIZE, 
                   epochs=30, callbacks=my_checkpointer)
# Out:
# Epoch 1/30
# 529/529 [==============================] - 188s 355ms/step - loss: 4.1890 - accuracy: 0.0767 - val_loss: 2.5352 - val_accuracy: 0.3229
#
# Epoch 00001: saving model to License_character_recognition.h5
# Epoch 2/30
# 529/529 [==============================] - 170s 321ms/step - loss: 1.9964 - accuracy: 0.4461 - val_loss: 0.6720 - val_accuracy: 0.8225
#
# Epoch 00002: saving model to License_character_recognition.h5
# Epoch 3/30
# 529/529 [==============================] - 171s 324ms/step - loss: 0.9846 - accuracy: 0.7267 - val_loss: 0.4388 - val_accuracy: 0.8801
#
# Epoch 00003: saving model to License_character_recognition.h5
# Epoch 4/30
# 529/529 [==============================] - 171s 323ms/step - loss: 0.7073 - accuracy: 0.8075 - val_loss: 0.3571 - val_accuracy: 0.8985
#
# Epoch 00004: saving model to License_character_recognition.h5
# Epoch 5/30
# 529/529 [==============================] - 170s 322ms/step - loss: 0.5687 - accuracy: 0.8450 - val_loss: 0.3126 - val_accuracy: 0.9147
#
# Epoch 00005: saving model to License_character_recognition.h5
# Epoch 6/30
# 529/529 [==============================] - 487s 921ms/step - loss: 0.4888 - accuracy: 0.8643 - val_loss: 0.2760 - val_accuracy: 0.9267
#
# Epoch 00006: saving model to License_character_recognition.h5
# Epoch 7/30
# 529/529 [==============================] - 348s 658ms/step - loss: 0.4327 - accuracy: 0.8785 - val_loss: 0.2510 - val_accuracy: 0.9309
#
# Epoch 00007: saving model to License_character_recognition.h5
# Epoch 8/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.3918 - accuracy: 0.8901 - val_loss: 0.2320 - val_accuracy: 0.9352ccuracy: 0. - ETA: 49s - loss: 0.3898 - accuracy: 0. - ETA: 39s - loss: 0.3918 - - ETA: 36s - loss: 0.3935 - accuracy: - ETA: 35s - loss: 0.3942 - accuracy: 0.888 - ETA: 34s - loss: 0.3945 - accuracy: - ETA: 33 - ETA: 26s - loss: 0.3 - ETA: 22s - loss: 0.3912 - ac - ETA: 19s - loss: - ETA: 14s - loss: 0.3921 - accuracy: - ETA: 13s - loss: 0.3917 - accurac - ETA: 2s - loss: 0.3 - ETA: 0s - loss: 0.3917 - accuracy: 0.89
#
# Epoch 00008: saving model to License_character_recognition.h5
# Epoch 9/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.3615 - accuracy: 0.8978 - val_loss: 0.2193 - val_accuracy: 0.9405loss: 0.3628 - accuracy - ETA: 36s - loss: 0.3627 - accura -  - ETA: 26s - loss: 0.3660 - ETA: 2
#
# Epoch 00009: saving model to License_character_recognition.h5
# Epoch 10/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.3321 - accuracy: 0.9058 - val_loss: 0.2110 - val_accuracy: 0.9407accuracy: 0. - ETA: 1:21 - loss: 0.3197 - accuracy: 0.90 - ETA: 1:20 - loss: 0.3196 - accuracy: 0.90 - ETA: 1:20 - loss: 0.3234 - accuracy: 0.90 - E - ETA: 1:03 - loss: 0.3318 -  - ETA: 1:01 - l - ETA: 57s - loss: 0.3335 - accurac - ETA: 56s - loss: 0 - - ETA: 34 - ETA: 28s - loss: 0.3282 - accuracy: 0.90 - ETA: 27s - loss: 0.3285 - accuracy: 0. - ETA: 26s - loss: 0.3289 - accuracy: 0.90 - ETA: 26s - loss: 0.3291 - accuracy: 0 - ETA: 25s - loss: 0.3295  - ETA: 22s - loss:  - ETA: 17s - - ETA: 11s - loss: 0 - ETA: 8s - loss: 0 - ETA: 5s - loss: 0.3325 - accu - ETA: 4s - loss: 0.3328 - accuracy: 0. - ETA: 4s - - ETA: 1s - loss: 0.3317 - ac
#
# Epoch 00010: saving model to License_character_recognition.h5
# Epoch 11/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.3193 - accuracy: 0.9090 - val_loss: 0.2001 - val_accuracy: 0.9495oss: 0.3298 - accuracy: 0. - ETA: 1:18 - loss: 0.3308  - ETA: 1:16 - los - ETA: 1:14 - loss: 0.3196 - accuracy: 0. - ETA: 1:13 - loss: 0.3185 - accuracy: 0.91 - ETA: 1:13 - loss: 0 - ETA: 1:11 - loss: 0.3184 - accu - ETA: 1:10 - loss: 0.3212 - ac - ETA: 1:04 - loss: 0.3223 - accu - ETA: 1:03 - loss: 0.3227 - accu - ETA: 1:02 - loss: 0.3245 - ac - ETA: 1:00 - loss: 0.3247 - accuracy: 0. - ETA: 1:00 - loss: 0.3238 - accur - ETA: 58s - loss: 0.3237 - acc - ETA: 56s - lo - ETA: 50s - loss: 0.3244 - accu - ETA: 48s - loss: 0.3266 - accuracy - ETA: 47s - loss: 0.3262 - accuracy: 0.9 - ETA: 46s - loss: 0.3271  - ETA: 43s - loss: 0.3294 - accuracy: 0 - ETA: 42 - ETA: 35s - loss: 0.3238 - accuracy: 0.908 - ETA: 35s - loss: 0.3240 - accuracy: 0.90 - ETA: 34s - loss: 0.3250  - ETA: 31s - loss: 0.3267 - accura - ETA: 29s - loss: 0.3259 - accuracy: - ET - ETA: 20s - loss: 0.3206 - accuracy: 0. - ETA: 19s - loss: 0.3203 -  - ETA: 16s - loss: 0.3220 - accuracy: 0. - ETA: 15s - loss: 0.3216 - accuracy: 0.90 - ETA: 15s - loss: 0.3217 - ac - ETA: 12 - - ETA:  - ETA: 0s - loss: 0.3182 - accuracy: 0.
#
# Epoch 00011: saving model to License_character_recognition.h5
# Epoch 12/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.2934 - accuracy: 0.9156 - val_loss: 0.1842 - val_accuracy: 0.95031:31 - loss: 0.2921 - accuracy: 0. - ETA: 1:31 - ETA: 1:23 - loss: 0.2959 - accura - - ETA - E - ETA: 45s - loss: 0.2857
#
# Epoch 00012: saving model to License_character_recognition.h5
# Epoch 13/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.2744 - accuracy: 0.9203 - val_loss: 0.1847 - val_accuracy: 0.950324 - loss: 0.2695 - accura - ETA: 1:23 - loss: 0.2755 - accuracy:  - ETA: 1:22 - loss: 0.2752  - ETA: 1:20 - loss: 0.2771 - accuracy:  - ETA: 1:15 - loss: - ETA: 1:13 - loss: 0.272 - ETA: 1:11 - loss: 0.2733 - accuracy - ETA: 1:10 - loss: 0.2715 - accuracy - ETA: 1:09 - loss: 0.2724 - accuracy:  - ETA: 1:09 - loss: 0.2710 -  - ETA: 1: - ETA: 1:04 - loss: 0. - ETA: 46s - loss: 0.2680 - accuracy: - ETA: 45s - loss: 0.2681 - accuracy: 0.92 - ETA: 45s - loss: 0.2687 - accuracy: 0.92 - ETA: 44s - loss: 0.2678 - accuracy: 0.9 - ETA: 44s - loss: 0.2674 - accuracy: 0 - ETA: 43s - loss: 0.2691 - accuracy: 0.92 - ETA: 42s - loss: 0.2689 - accu - ETA: 40s - loss: 0.2708 - accuracy:  - ETA: 39s - loss: 0.2711 - accuracy: 0 - ETA: 38s - loss: 0.2713 - accuracy - ETA: 36s - loss: 0.2722 - acc - ETA: 34s - loss: 0.2722 - accuracy: 0. - ETA: 3 - ETA: 26s - loss: 0.2690 - a - ETA: 23s - loss: 0.2701 - accuracy: 0.92 - ETA: 23s - loss: 0.2698 - accuracy - ETA: 22s - loss: 0.2693 - - ETA: 18s - loss: - ETA: 13s - loss: 0.2722 - a - ETA: 10s - loss: 0.2721 - accuracy: 0.9 - ETA: 10s - ETA: 6s - loss: 0.274 - ETA: 4s - loss: 0.2 - ETA: 2s - l
#
# Epoch 00013: saving model to License_character_recognition.h5
# Epoch 14/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.2612 - accuracy: 0.9239 - val_loss: 0.1715 - val_accuracy: 0.9554ETA: 57s - loss: 0.249 - ETA: 54s - loss: 0.2499 - accuracy:  - ETA: 52s - l - ETA: 38s - loss: 0.2555 - accuracy: 0.92 - ETA: 38s - loss: 0 - ETA: 33s - loss: 0.2573 - accura - ETA: 31s - loss: 0.2583 - accura - ETA: 29s - loss: 0.2594 - ac - ETA: 27s - loss: 0.2604 - a - ETA: 24s - loss: 0.2610 - accuracy:  - ETA: 23s - loss: 0.2612 - accur - ETA: 21s - loss: 0.2608 - - ETA: 17s - loss: 0.26 - ETA: 13s - loss: 0.2623 - ac - ETA: 11s - loss: 0.2633 - accuracy: 0.9 - ETA: 10s - loss:  - ETA: 7s - loss: 0.2622 - accuracy - ETA: 7s - ETA: 3s - loss: 0.2618 - accuracy: 0.92 - ETA
#
# Epoch 00014: saving model to License_character_recognition.h5
# Epoch 15/30
# 529/529 [==============================] - 107s 202ms/step - loss: 0.2454 - accuracy: 0.9268 - val_loss: 0.1678 - val_accuracy: 0.9546: 54s - loss: 0.2444 - accuracy: 0.926 - ETA: 54s - loss: 0.2443 - accu - ETA: 51s - loss: 0.2426 - accura - ETA: 49s - loss: 0.2396 - ETA: 11s - loss: 0.2455 - accuracy - ETA: 9s - loss: 0.2456  - ETA: 3s - loss: 0.2457 - ac - ETA: 2s - loss: 0
#
# Epoch 00015: saving model to License_character_recognition.h5
# Epoch 16/30
# 529/529 [==============================] - 107s 201ms/step - loss: 0.2356 - accuracy: 0.9296 - val_loss: 0.1682 - val_accuracy: 0.9548- accuracy: 0.928 - ETA: 32s - loss: 0.2368 - accuracy: 0.92 - ETA: 31s - loss: 0.2371 - accuracy: 0.928 - ETA: 31s - loss: 0.2370 - accuracy: 0.928 - ETA: 31s - loss:  - ETA: 26s - loss: 0.2357 - accuracy: 0 - ETA: 25s - loss: 0.2347 - accuracy - ETA: 24s - loss: 0.2348 - accuracy:  - ETA: 23s - loss: 0.2 - ETA: 5s - loss: 0.2349 - accuracy: 0.92 - ETA: 5s - loss: 0.2352 - accu
#
# Epoch 00016: saving model to License_character_recognition.h5
# Epoch 17/30
# 529/529 [==============================] - 107s 201ms/step - loss: 0.2223 - accuracy: 0.9331 - val_loss: 0.1569 - val_accuracy: 0.9567 - ETA: 1:04  - ETA: 45s - loss: 0.2237 - - ETA: 41s - loss: 0.2230 - accuracy:  - ET - ETA: 33s - loss: 0.2206 - accuracy: 0 - ETA: 32s - loss: 0.2212 - accuracy - ETA: 30s - loss: 0.2191 - accu - ETA:  - ETA: 12s - loss:
#
# Epoch 00017: saving model to License_character_recognition.h5
# Epoch 18/30
# 529/529 [==============================] - 106s 201ms/step - loss: 0.2103 - accuracy: 0.9369 - val_loss: 0.1507 - val_accuracy: 0.9585oss: 0.2 - ETA: - ETA: 54s - loss: 0.2134 - - ETA: 50s - loss: 0.2163 - acc - ETA: 48s - loss - ETA: 43s - loss: 0.2163 - accuracy: 0.9 - ETA: 33s - loss: 0.2139 -  - ET - ETA: 2
#
# Epoch 00018: saving model to License_character_recognition.h5
# Epoch 19/30
# 529/529 [==============================] - 106s 201ms/step - loss: 0.2063 - accuracy: 0.9377 - val_loss: 0.1404 - val_accuracy: 0.9623TA: 1:24 - loss: 0.1934  - ETA - ETA: 1:09 - loss: 0.1923 - accuracy - ETA: 1:09 - loss: 0.1931 - accuracy: 0.94 - ETA: 1:09 - ETA: 54s - loss: 0.2011 - accuracy - ETA: 52s - loss: 0.2006 - ETA: 48s - loss: 0.1998 - accuracy: 0.939 - ETA: 48s - loss: 0.199 - ETA: 44s - lo - ETA: 39s - lo - ETA: 33s - loss: 0.2009 - accurac - ETA: 32s - loss: 0.2019 - accuracy: 0. - ETA: 31s - loss - ETA: 26s - loss: 0.2037 - accuracy: 0.938 - ETA: 25s - loss: 0.2040 - accuracy: 0.93 - ETA: 25s - loss: 0.2041 - accur - ETA
#
# Epoch 00019: saving model to License_character_recognition.h5
# Epoch 20/30
# 529/529 [==============================] - 106s 201ms/step - loss: 0.1915 - accuracy: 0.9413 - val_loss: 0.1369 - val_accuracy: 0.96317 - ac - ETA: 1:13 - loss: 0.1949 - accuracy: 0.93 - ETA: 1:13 - los - - ETA: 1:01 - loss: 0.1933 -  - ETA: 1:00 - loss: 0.1925 - ac - ETA: 57s - loss: 0.1924 - acc - ETA: 55s - loss: 0.1928 - accurac - ETA: 53s - loss: 0.1918 - accuracy: 0.940 - ETA: 53s - loss: 0.1921 - a - ETA: 41s - loss: 0.1921 - accuracy: 0.940 - ETA: 4 - ETA: 9s - loss: 0.191 - ETA: 7s - loss: 0.1 - ETA: 5s - l - ETA: 2s - loss: 0.1914 - accuracy: 0. - ETA: 1s - loss: 0.191
#
# Epoch 00020: saving model to License_character_recognition.h5
# Epoch 21/30
# 529/529 [==============================] - 106s 201ms/step - loss: 0.1897 - accuracy: 0.9416 - val_loss: 0.1452 - val_accuracy: 0.95691:09 - - ETA: 1:01 - loss: 0.188 - ETA: 59s - loss: 0.1896 - ac - ETA: 56s - loss: 0.1904 - accuracy: 0.94 - ETA: 56s - loss: 0.1901 - accuracy: 0.941 - ETA: 55s - loss: 0.1898 - accur - ETA: 53s - - ET - ETA: 39s - loss: 0.1922 - accuracy: 0. - ETA: 39s - loss: 0.1928 - accuracy: 0.9 - ETA: 38s - loss: 0.1925 - accuracy: 0.94 - ETA: 38s - loss: 0. - ETA: 33s - loss: 0.1926 - accurac - ETA: 32s - loss: 0.1929 -  - ETA: 29s - loss: 0.1911 - accuracy: - ETA: 27s - loss: 0.1907 - accuracy: - ETA: 26s - loss: 0.1902 - accuracy
#
# Epoch 00021: saving model to License_character_recognition.h5
# Epoch 22/30
# 529/529 [==============================] - 107s 201ms/step - loss: 0.1834 - accuracy: 0.9438 - val_loss: 0.1389 - val_accuracy: 0.9577oss: 0.1685 - accuracy:  - ETA: 1:27 - loss: 0.1 - ETA: 1:21 - loss: 0.1775 - accuracy:  - ETA: 1:16 - loss: 0.1722 - accuracy:  - ETA:  - ETA: 57s - loss: 0.1800 - accuracy: 0.943 - ETA: 57s - los - ETA: 51s - loss: 0.1841 - accuracy: 0.9 - - ETA: 42s - loss: 0.1864 -  - ETA: 39s - loss: 0.1861 - ETA: 36s - loss: 0.1856 - accuracy: 0.94 - ETA: 35s - loss: 0.1860 - accura  - ETA: 25s - loss: 0.1852 - accura - ETA: 7s - loss: 0.1846  - ETA: 6s - loss: 0.184
#
# Epoch 00022: saving model to License_character_recognition.h5
# Epoch 23/30
# 529/529 [==============================] - 106s 201ms/step - loss: 0.1758 - accuracy: 0.9443 - val_loss: 0.1231 - val_accuracy: 0.963938 - loss: 0.1902 -  - ETA: 1:37 - loss: 0.1765 - accura - ETA: 1:36 - loss: 0.1 - ETA: 1:34 - los - - ETA:  - ETA: 53s - loss: 0.1821 - accura - ETA: 51s - loss: 0.1814 - accu - ETA: 49s - loss: 0.1812 -  - ETA: 46s - loss: 0.1800 - accuracy: 0.94 - ETA: 45s - l - ETA: 40s - los - ETA: 34s - loss: 0.1785 - accuracy: 0.94 - ETA: 34s - loss:  - ETA: 29s - loss: 0.1784 - accurac - ETA: 27s - loss: 0.1785 - accuracy: 0.943 - ETA: 27s - loss: 0.1783 - acc - ETA: 24s - loss: 0.1789 -  - ETA: 21s -
#
# Epoch 00023: saving model to License_character_recognition.h5
# Epoch 24/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.1678 - accuracy: 0.9468 - val_loss: 0.1263 - val_accuracy: 0.9647s: 0.1697 - ac - ETA: 1:10 - loss: 0.1708 - accuracy:  - ETA: 1:10 - loss: 0.1716 - accu - ETA: 1:09 - ETA: 1:05 - loss: - ETA: 1:03 - loss: 0.1722 - accura - ETA: 1:02 - loss: 0 - ETA: 1:00 - loss: 0.1700 - accuracy: 0. - ETA: 59s - loss: 0.1694 - accuracy -  - ETA: 49s - loss: 0.1687  - ETA: - ETA: 30s - loss: 0.1681 - accuracy: 0.946 - ETA: 30s - loss: 0.1683 - accuracy: 0 - ETA: 29s - loss: 0.169 - ETA: 25s - loss: 0.1684 -  - ETA: 22s - loss: 0.1 - ETA: 18s - loss: 0.1668 - accuracy: 0.94 - ETA: 17s - loss: 0.1662 - accuracy - ETA: 16s - loss: 0.1659 - accuracy: 0.94 - ETA: 15s - loss: 0.1662 - accuracy: 0 - ETA: 14s - loss: 0.1663 - accuracy: 0.947 - ETA: 14s - loss: 0.1662 - a - ETA: 11s - loss - ETA:  - ETA: 4s - loss: 0.1686 - accuracy: 0. - ETA: 4s - loss: 0.1688 -  - ETA: 2s - l
#
# Epoch 00024: saving model to License_character_recognition.h5
# Epoch 25/30
# 529/529 [==============================] - 106s 201ms/step - loss: 0.1612 - accuracy: 0.9478 - val_loss: 0.1231 - val_accuracy: 0.9649
#
# Epoch 00025: saving model to License_character_recognition.h5
# Epoch 26/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.1543 - accuracy: 0.9513 - val_loss: 0.1127 - val_accuracy: 0.9665oss: 0.1614 - accura - ETA: 1:09 - loss: 0.1637 - accu - ETA: 1:08 - loss: 0.1636 -  - ETA: 1:06 - loss: 0.1631 -  - ETA: 1:04 - loss: 0 - ETA: 1:0 - ETA: 58s - loss: - ETA: 53s - loss: 0.1595 - accura - ETA: 51s - loss: 0.1575 - accu - ETA: 4 - ETA: 42s -  - ETA: 36s - loss: 0.1573  - ETA: 33s - loss: 0.1573 - a - ETA: 30s - loss: 0.1572 - accuracy: 0. - ETA: 29s - loss: 0.1566 - accur - ETA: 27s - loss: 0.1569 - accuracy: 0.95 - ETA: 1s - loss: 0.1543 - accu
#
# Epoch 00026: saving model to License_character_recognition.h5
# Epoch 27/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.1533 - accuracy: 0.9522 - val_loss: 0.1125 - val_accuracy: 0.9670 - ETA: 1:28 - loss: 0 - ETA: 1:13 - loss: 0.1492 - ac - E - ETA:  - ETA - ETA: 1:00 - loss: 0.1455 - acc - ETA: 49s - loss: 0.1452 - accur - ETA: 47s - loss: 0.1442 - ETA: 43s - loss: 0.1440 - accuracy: 0. - ETA: 42s - loss: 0.1446 - accu - ETA
#
# Epoch 00027: saving model to License_character_recognition.h5
# Epoch 28/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.1538 - accuracy: 0.9505 - val_loss: 0.1115 - val_accuracy: 0.9676- accuracy - ETA: 1:05 - - ETA: 1:01 - loss: 0.1540 - accu - ETA: 1:00 - loss: 0.1554 - accuracy - ETA: 59s - loss: 0.1555 - accuracy: - ETA: 58s - loss: 0.1551 - accuracy: 0. - ET - ETA: 49s - loss: 0.1573 - ETA: 46s - loss:  - ETA: 41s - loss: 0.1 - ETA: 37s - loss: 0.1559 - accuracy: 0.95 - ETA: 36s - loss: 0.1 - ETA: 32s - loss: 0.1550 - accuracy: 0.9 - ETA: 31s - loss: 0.1546 - accuracy: 0. - ETA: 31s - loss: 0.1540 - accuracy: 0.950 - ETA: 30s - loss: 0.1537 - accu - ETA: 28s - loss: 0.1545 - accuracy: 0.950 - ETA: 28s - loss: 0.1541 - ETA: 24s - loss: 0.1535 - accuracy: 0. - ETA: 24s - loss: 0.1535 - accur - ETA: 21s - loss: 0.1532 - accuracy:  - ETA: 20s - loss: 0.1533 - ac - ETA: 18s - loss: 0.1544 - accuracy: 0.9 - ETA: 17s - loss: 0.1548 - ac - ETA: 14s - loss: 0.1539  - ETA: 11s - loss: 0.1540 - accuracy: 0 - ETA: 10s - loss: 0.1541 - accuracy: 0.950 - ETA: 10s - loss: 0.1541 - accur - ETA: 4s - loss: 0.1543 - accu - ETA: 3s - loss: 0.1542 - accuracy:  - ETA: 3s - loss: 0.1543 - accuracy: 0.95 - ETA: 2s - l
#
# Epoch 00028: saving model to License_character_recognition.h5
# Epoch 29/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.1393 - accuracy: 0.9558 - val_loss: 0.1172 - val_accuracy: 0.9633- ETA: 57s - loss: 0.1378 - accuracy - ETA: 55s - loss: 0.1372 - accuracy: - ETA: 45s - loss: 0.13 - ETA: 41s - loss: 0.1372 - accuracy: 0.95 - ETA: 41s - los - ETA: 35s - loss: 0.1379 - accuracy: - ETA: 34s - loss: 0.1382 - accuracy: 0. - ETA: 33s - loss: 0.13 - ETA: 21s - loss: 0.1403 - accurac - ETA: 19s - loss: 0.1 - ETA: 15s - loss: - ETA: 1s - loss: 0.1398 -
#
# Epoch 00029: saving model to License_character_recognition.h5
# Epoch 30/30
# 529/529 [==============================] - 106s 200ms/step - loss: 0.1360 - accuracy: 0.9569 - val_loss: 0.1006 - val_accuracy: 0.9700- loss: 0.1348 - accur - ETA: 49s - loss - ETA: 44s - loss: 0.1348 - accur - ETA: 42s - loss: 0.1347 - accuracy - ETA: 40s - loss: 0.1364 - accuracy: 0.95 - ETA: 40s - loss: 0.1365 - acc - ETA: 38s - loss: 0.1360  - ETA: 34s - loss: 0.1360 - accuracy: 0.9 - ETA: 34s - loss: 0.1362  - ETA: 30s - loss: 0.1365 - accuracy: - ETA: 29s - loss: 0.1362 - accuracy: 0.956 - ETA: 29s - loss: 0.1363 - accuracy: 0.95 - ETA: 28s - loss: 0.1362 - accuracy:  - ETA: 27s - loss: 0. - ETA: 23s - loss: 0.1362 - accuracy: 0.95 - ETA: 22s - loss: 0.1359 -  - ET - ETA: 11s - loss:
#
# Epoch 00030: saving model to License_character_recognition.h5

# %%
model.save('plate_char_recognition.h5')
